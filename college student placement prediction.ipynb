# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\Admin\Documents\collegePlace.csv')
print(df)
# Out:
#     Age  Gender       Stream  intenship  CGPA  Hostel  History off Backlog  \
# 0    22    male    Electonic          1     8       1                    1
# 1    21  female     Computer          0     7       1                    1
# 2    21    male  information          1     9       1                    1
# 3    22  female     Computer          1     8       1                    1
# 4    21  female        civil          0     9       1                    0
# 5    22    male    Electonic          0     8       1                    1
# 6    22  female  information          1     9       0                    0
# 7    21  female        civil          1     7       0                    0
# 8    21    male     Computer          1     8       0                    0
# 9    22    male     Computer          1     9       0                    1
# 10   22  female        civil          1     7       1                    1
#
#     Placed or Not
# 0               1
# 1               1
# ...

# %%
df.head()
# Out:
#    Age  Gender       Stream  intenship  CGPA  Hostel  History off Backlog  \
# 0   22    male    Electonic          1     8       1                    1
# 1   21  female     Computer          0     7       1                    1
# 2   21    male  information          1     9       1                    1
# 3   22  female     Computer          1     8       1                    1
# 4   21  female        civil          0     9       1                    0
#
#    Placed or Not
# 0              1
# 1              1
# 2              1
# 3              0
# 4              0

# %%
df.shape
# Out:
# (11, 8)

# %%
df['Gender'].replace({'male':0,'female':1},inplace=True)
df
# Out:
#     Age  Gender       Stream  intenship  CGPA  Hostel  History off Backlog  \
# 0    22       0    Electonic          1     8       1                    1
# 1    21       1     Computer          0     7       1                    1
# 2    21       0  information          1     9       1                    1
# 3    22       1     Computer          1     8       1                    1
# 4    21       1        civil          0     9       1                    0
# 5    22       0    Electonic          0     8       1                    1
# 6    22       1  information          1     9       0                    0
# 7    21       1        civil          1     7       0                    0
# 8    21       0     Computer          1     8       0                    0
# 9    22       0     Computer          1     9       0                    1
# 10   22       1        civil          1     7       1                    1
#
#     Placed or Not
# 0               1
# 1               1
# ...

# %%
df['Stream'].unique()
# Out:
# array(['Electonic', 'Computer', 'information', 'civil'], dtype=object)

# %%
df.head()
# Out:
#    Age  Gender       Stream  intenship  CGPA  Hostel  History off Backlog  \
# 0   22       0    Electonic          1     8       1                    1
# 1   21       1     Computer          0     7       1                    1
# 2   21       0  information          1     9       1                    1
# 3   22       1     Computer          1     8       1                    1
# 4   21       1        civil          0     9       1                    0
#
#    Placed or Not
# 0              1
# 1              1
# 2              1
# 3              0
# 4              0

# %%
df['Stream'].replace({'Electonic':0,'Computer':1,'information':2,'civil':3},inplace=True)
df
# Out:
#     Age  Gender  Stream  intenship  CGPA  Hostel  History off Backlog  \
# 0    22       0       0          1     8       1                    1
# 1    21       1       1          0     7       1                    1
# 2    21       0       2          1     9       1                    1
# 3    22       1       1          1     8       1                    1
# 4    21       1       3          0     9       1                    0
# 5    22       0       0          0     8       1                    1
# 6    22       1       2          1     9       0                    0
# 7    21       1       3          1     7       0                    0
# 8    21       0       1          1     8       0                    0
# 9    22       0       1          1     9       0                    1
# 10   22       1       3          1     7       1                    1
#
#     Placed or Not
# 0               1
# 1               1
# 2               1
# 3               0
# 4               0
# ...

# %%
df.head()
# Out:
#    Age  Gender  Stream  intenship  CGPA  Hostel  History off Backlog  \
# 0   22       0       0          1     8       1                    1
# 1   21       1       1          0     7       1                    1
# 2   21       0       2          1     9       1                    1
# 3   22       1       1          1     8       1                    1
# 4   21       1       3          0     9       1                    0
#
#    Placed or Not
# 0              1
# 1              1
# 2              1
# 3              0
# 4              0

# %%
df.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Stream                 0
# intenship              0
# CGPA                   0
# Hostel                 0
# History off Backlog    0
# Placed or Not          0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
age=df['Age']                    
gender=df['Gender']                 
stream=df['Stream']                
intenship=df['intenship']             
cgpa=df['CGPA']                   
hostel=df['Hostel']                 
historyofbacklog=df['History off Backlog']    
y=df['Placed or Not']
df
# Out:
#     Age  Gender  Stream  intenship  CGPA  Hostel  History off Backlog  \
# 0    22       0       0          1     8       1                    1
# 1    21       1       1          0     7       1                    1
# 2    21       0       2          1     9       1                    1
# 3    22       1       1          1     8       1                    1
# 4    21       1       3          0     9       1                    0
# 5    22       0       0          0     8       1                    1
# 6    22       1       2          1     9       0                    0
# 7    21       1       3          1     7       0                    0
# 8    21       0       1          1     8       0                    0
# 9    22       0       1          1     9       0                    1
# 10   22       1       3          1     7       1                    1
#
#     Placed or Not
# 0               1
# 1               1
# 2               1
# 3               0
# 4               0
# ...

# %%
plt.scatter(age,y)

# %%
Y=df['Placed or Not']
X=df.drop(['Placed or Not'],axis=1)
df
# Out:
#     Age  Gender  Stream  intenship  CGPA  Hostel  History off Backlog  \
# 0    22       0       0          1     8       1                    1
# 1    21       1       1          0     7       1                    1
# 2    21       0       2          1     9       1                    1
# 3    22       1       1          1     8       1                    1
# 4    21       1       3          0     9       1                    0
# 5    22       0       0          0     8       1                    1
# 6    22       1       2          1     9       0                    0
# 7    21       1       3          1     7       0                    0
# 8    21       0       1          1     8       0                    0
# 9    22       0       1          1     9       0                    1
# 10   22       1       3          1     7       1                    1
#
#     Placed or Not
# 0               1
# 1               1
# 2               1
# 3               0
# 4               0
# ...

# %%
X
# Out:
#     Age  Gender  Stream  intenship  CGPA  Hostel  History off Backlog
# 0    22       0       0          1     8       1                    1
# 1    21       1       1          0     7       1                    1
# 2    21       0       2          1     9       1                    1
# 3    22       1       1          1     8       1                    1
# 4    21       1       3          0     9       1                    0
# 5    22       0       0          0     8       1                    1
# 6    22       1       2          1     9       0                    0
# 7    21       1       3          1     7       0                    0
# 8    21       0       1          1     8       0                    0
# 9    22       0       1          1     9       0                    1
# 10   22       1       3          1     7       1                    1

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.1)

# %%
from xgboost import XGBClassifier

# %%
clf=XGBClassifier(learning_rate=0.09,
                 n_estimators=150)

# %%
clf.fit(X_train,Y_train,eval_metric='logloss')
# Out:
# C:\Anaconda3\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.09, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=150,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
type(stream[1])
# Out:
# numpy.int64

# %%
gender=df['Gender']

# %%
predictions=clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,precision_score,recall_score,accuracy_score,roc_auc_score
print("accuracy_score:" + str(accuracy_score(Y_test,predictions)))
# Out:
# accuracy_score:1.0

# %%
import cv2
import pandas as pd
#data=pd.read_csv(r'C:\Users\Admin\Documents\Zpp.xlsx')
df=pd.read_CSV(r'C:\Users\Admin\Documents\Zpp.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-2fa623849b99> in <module>
#       2 import pandas as pd
#       3 #data=pd.read_csv(r'C:\Users\Admin\Documents\Zpp.xlsx')
# ----> 4 df=pd.read_CSV(r'C:\Users\Admin\Documents\Zpp.csv')
#
# C:\Anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     256             return _SparseArray
#     257
# --> 258         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     259
#     260
#
# AttributeError: module 'pandas' has no attribute 'read_CSV'

# %%
print(df)
# Out:
#     Age  Gender  Stream  intenship  CGPA  Hostel  History off Backlog  \
# 0    22       0       0          1     8       1                    1
# 1    21       1       1          0     7       1                    1
# 2    21       0       2          1     9       1                    1
# 3    22       1       1          1     8       1                    1
# 4    21       1       3          0     9       1                    0
# 5    22       0       0          0     8       1                    1
# 6    22       1       2          1     9       0                    0
# 7    21       1       3          1     7       0                    0
# 8    21       0       1          1     8       0                    0
# 9    22       0       1          1     9       0                    1
# 10   22       1       3          1     7       1                    1
#
#     Placed or Not
# 0               1
# 1               1
# 2               1
# 3               0
# 4               0
# ...
